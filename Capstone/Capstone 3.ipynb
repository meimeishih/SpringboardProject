# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df1=pd.read_csv('heart.csv')
df1.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df1.shape
# Out:
# (303, 14)

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
column_list=list(df1)
print(column_list)
# Out:
# ['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh', 'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output']

# %%
df1.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64
# dtype: object

# %%
df1.count()
# Out:
# age         303
# sex         303
# cp          303
# trtbps      303
# chol        303
# fbs         303
# restecg     303
# thalachh    303
# exng        303
# oldpeak     303
# slp         303
# caa         303
# thall       303
# output      303
# dtype: int64

# %%
print(df1.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df1.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
#count on all categorical Data

fig = plt.figure(figsize=(20,20))
gs = fig.add_gridspec(3,3)
gs.update(wspace=0.5, hspace=0.25)
ax0 = fig.add_subplot(gs[0,0])
ax1 = fig.add_subplot(gs[0,1])
ax2 = fig.add_subplot(gs[0,2])
ax3 = fig.add_subplot(gs[1,0])
ax4 = fig.add_subplot(gs[1,1])
ax5 = fig.add_subplot(gs[1,2])
ax6 = fig.add_subplot(gs[2,0])
ax7 = fig.add_subplot(gs[2,1])


sns.countplot(ax=ax0,x='sex',data = df1)
sns.countplot(ax=ax1,x='exng',data = df1)
sns.countplot(ax=ax2,x='caa',data = df1)
sns.countplot(ax=ax3,x='cp',data = df1)
sns.countplot(ax=ax4,x='fbs',data = df1)
sns.countplot(ax=ax5,x='restecg',data = df1)
sns.countplot(ax=ax6,x='slp',data = df1)
sns.countplot(ax=ax7,x='thall',data = df1)
# Out:
# <AxesSubplot:xlabel='thall', ylabel='count'>

# %%
#count output by sex: 0= male, 1=female
df1.groupby('output')['sex'].value_counts().unstack().plot.bar(stacked=False)
# Out:
# <AxesSubplot:xlabel='output'>

# %%
#count output by Chest Pain Type: 0 = typical angina, 1 = atypical angina, 3= non=angina pain, 4= asymptomatic
df1.groupby('output')['cp'].value_counts().unstack().plot.bar(stacked=False)
# Out:
# <AxesSubplot:xlabel='output'>

# %%
#count output by  exercise induced angina: 0= no, 1 = yes
df1.groupby('output')['exng'].value_counts().unstack().plot.bar(stacked=False)
# Out:
# <AxesSubplot:xlabel='output'>

# %%
#count output by number of major vessels
df1.groupby('output')['caa'].value_counts().unstack().plot.bar(stacked=False)
# Out:
# <AxesSubplot:xlabel='output'>

# %%
#count output by resting electrocardiographic result: 0=normal, 1=Having ST-T wave abnormally, 2= showing probable or definite left ventricular hypertrophy by Estes' criteria
df1.groupby('output')['restecg'].value_counts().unstack().plot.bar(stacked=False)
# Out:
# <AxesSubplot:xlabel='output'>

# %%
Age=df1[['age','output']]
bins=[0,18,30,40,50,60,70,100]
labels=['0-17','18-29','30-39','40-49','50-59','60-69','70+']
Age['Agerange']=pd.cut(Age.age,bins,labels=labels, include_lowest=True)
# Out:
# C:\Users\meime\AppData\Local\Temp/ipykernel_34684/581229325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Age['Agerange']=pd.cut(Age.age,bins,labels=labels, include_lowest=True)

# %%
#cout output by AgeGroup
Age.groupby('output')['Agerange'].value_counts().unstack().plot.bar(stacked=False)
# Out:
# <AxesSubplot:xlabel='output'>

# %%
fig = plt.figure(figsize=(20,20))

sns.displot(data= df1.age, label="Age", kde= True)
plt.legend()
sns.displot(data= df1.trtbps,color="red", label="Resting Blood Pressure", kde= True)
plt.legend()
sns.displot(data= df1.thalachh,color="green", label="Maximum Heart Rate", kde= True)
plt.legend()
sns.displot(data= df1.chol,color="brown", label="Cholestrol", kde= True)
plt.legend()

# %%
plt.figure(figsize=(10,10))
sns.histplot(data=df1,x='chol',hue='output' ,kde=True)
plt.title('Heart Attack v/s Chol')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.histplot(data=df1,x='trtbps',hue='output' ,kde=True)
plt.title('Heart Attack v/s Resting Blood Pressure')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.histplot(data=df1,x='thalachh',hue='output' ,kde=True)
plt.title('Heart Attack v/s Maximum HR Achieved')
plt.show()

# %%
sns.pairplot(df1)

# %%
df_corr = df1.corr().transpose()
sns.set(rc={'figure.figsize':(20,20)})
sns.heatmap(df_corr, annot =True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
df1.boxplot(by='output',column=['trtbps','chol','fbs','thalachh','oldpeak'],figsize=(20,20),grid=False)
# Out:
# array([[<AxesSubplot:title={'center':'trtbps'}, xlabel='output'>,
#         <AxesSubplot:title={'center':'chol'}, xlabel='output'>],
#        [<AxesSubplot:title={'center':'fbs'}, xlabel='output'>,
#         <AxesSubplot:title={'center':'thalachh'}, xlabel='output'>],
#        [<AxesSubplot:title={'center':'oldpeak'}, xlabel='output'>,
#         <AxesSubplot:>]], dtype=object)

# %%
from sklearn.model_selection import train_test_split

y = df1[['output']]
X = df1.drop(columns='output')

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.model_selection import validation_curve
from sklearn import metrics

LR=LogisticRegression()
LR.fit(X_train,y_train)

print(accuracy_score(LR.predict(X_test),y_test))
# Out:
# 0.8571428571428571
# C:\Users\meime\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
y_pred_proba = LR.predict_proba(X_test)[::,1]
fpr,tpr,_=metrics.roc_curve(y_test, y_pred_proba)
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

auc = metrics.roc_auc_score(y_test, y_pred_proba)

print(auc)
# Out:
# 0.9396135265700483

# %%
#Tune 
Cs = [0.001, 0.1, 1, 10, 100]
param_grid = {'C': Cs}
LR = LogisticRegression()
LR_cv = GridSearchCV(LR, param_grid)
LR_cv.fit(X_train,y_train)
print(LR_cv.best_params_)
print(LR_cv.best_score_)
# Out:
# {'C': 1}
# 0.8307862679955702
# C:\Users\meime\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\meime\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\meime\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

#Gradient Boosting for Triage Only - Find best Learning Rate
learning_rates = [0.05, 0.1, 0.25, 0.5, 0.75, 1]
for learning_rate in learning_rates:
    gb = GradientBoostingClassifier(learning_rate = learning_rate)
    gb.fit(X_train, y_train)
    print("Learning rate: ", learning_rate)
    print("Accuracy score (training): {0:.3f}".format(gb.score(X_train, y_train)))
    print("Accuracy score (validation): {0:.3f}".format(gb.score(X_test, y_test)))
    print()
# Out:
# Learning rate:  0.05
# Accuracy score (training): 0.967
# Accuracy score (validation): 0.791
# C:\Users\meime\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\meime\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\meime\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %%
gb = GradientBoostingClassifier(learning_rate = 0.5)
gb_model = gb.fit(X_train, y_train)
y_pred = gb_model.predict(X_test)
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred))
print('Classification Report:\n', classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[34 11]
#  [13 33]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74        45
#            1       0.75      0.72      0.73        46
#
#     accuracy                           0.74        91
#    macro avg       0.74      0.74      0.74        91
# weighted avg       0.74      0.74      0.74        91
# C:\Users\meime\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#AUC for Triage only GB model
gby_pred_proba = gb_model.predict_proba(X_test)[::,1]
fgbpr,tgbpr,_=metrics.roc_curve(y_test, y_pred_proba)
plt.plot(fgbpr,tgbpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
gbauc = metrics.roc_auc_score(y_test, gby_pred_proba)
print(gbauc)
# Out:
# 0.8685990338164251

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score

SVC = svm.SVC(probability=True)
SVC_model=SVC.fit(X_train, y_train)
  
predicted = SVC.predict(X_test)
print(accuracy_score(y_test, predicted))
# Out:
# 0.8461538461538461
# C:\Users\meime\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
SVCy_pred_proba = SVC_model.predict_proba(X_test)[::,1]
fSVCpr,tSVCpr,_=metrics.roc_curve(y_test, y_pred_proba)
plt.plot(fSVCpr,tSVCpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
SVCauc = metrics.roc_auc_score(y_test, SVCy_pred_proba)
print(SVCauc)
# Out:
# 0.9227053140096618
